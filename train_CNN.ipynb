# %%
from MLP import *
from CNN import *

# %%
from keras.datasets import mnist
(x_train,y_train),(x_test,y_test) = mnist.load_data()

def one_hot(Y):
  one_hot_Y = np.zeros((Y.size,np.max(Y) + 1))
  one_hot_Y[np.arange(Y.size),Y] = 1
  one_hot_Y = one_hot_Y.T
  return one_hot_Y


y_train = one_hot(y_train)
y_test = one_hot(y_test)
x_train = x_train/255
x_test = x_test/255
x_validation = x_train[59000:60000]
y_validation = y_train[:,59000:60000]
x_train = x_train[0:1000]
y_train = y_train[:,0:1000]

print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (1000, 28, 28) (10, 1000)
# (10000, 28, 28) (10, 10000)

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 4, l_rate = 0.1)
pool1 = MaxPoolingLayer(2)
CNN2 = Convolutional(input_shape = (4,13,13), kernel_size = 3,output_depth = 8, l_rate = 0.1)
pool2 = MaxPoolingLayer(2)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[288,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.1) # 8*6*6 = 288
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 64, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# epochs:  0 loss:  12.478734506881676 accuracy_train: 0.083 loss_val 12.576088804996896 accuracy_validation: 0.075
# epochs:  1 loss:  11.413783710548348 accuracy_train: 0.149 loss_val 11.594890488071455 accuracy_validation: 0.135
# epochs:  2 loss:  10.230515363905479 accuracy_train: 0.233 loss_val 10.342977428314537 accuracy_validation: 0.221
# epochs:  3 loss:  8.917152238317767 accuracy_train: 0.321 loss_val 9.232049624058723 accuracy_validation: 0.301
# epochs:  4 loss:  7.9924681832289135 accuracy_train: 0.387 loss_val 8.194082440049147 accuracy_validation: 0.373
# epochs:  5 loss:  6.949420235308975 accuracy_train: 0.473 loss_val 7.316034877875878 accuracy_validation: 0.441
# epochs:  6 loss:  6.657652652305045 accuracy_train: 0.486 loss_val 7.022948721380315 accuracy_validation: 0.464
# epochs:  7 loss:  6.577168543866228 accuracy_train: 0.495 loss_val 7.131242644644192 accuracy_validation: 0.458
# epochs:  8 loss:  5.803828709867923 accuracy_train: 0.557 loss_val 6.119690486390173 accuracy_validation: 0.539
# epochs:  9 loss:  5.294265783893905 accuracy_train: 0.599 loss_val 5.921380225613323 accuracy_validation: 0.556
# epochs:  10 loss:  5.042700019951871 accuracy_train: 0.617 loss_val 5.506210202380578 accuracy_validation: 0.581
# epochs:  11 loss:  5.00934768188649 accuracy_train: 0.61 loss_val 5.553855273291078 accuracy_validation: 0.579
# epochs:  12 loss:  5.1440308218428 accuracy_train: 0.601 loss_val 5.648410677472374 accuracy_validation: 0.571
# epochs:  13 loss:  5.264380055383403 accuracy_train: 0.601 loss_val 5.957121048559161 accuracy_validation: 0.555
# epochs:  14 loss:  5.336429823390002 accuracy_train: 0.594 loss_val 6.096980768561284 accuracy_validation: 0.544
# epochs:  15 loss:  5.08944193468137 accuracy_train: 0.611 loss_val 5.880310886376344 accuracy_validation: 0.556
# epochs:  16 loss:  4.694739204501481 accuracy_train: 0.635 loss_val 5.666212638784411 accuracy_validation: 0.574
# epochs:  17 loss:  4.756615018356075 accuracy_train: 0.636 loss_val 5.9223639679199955 accuracy_validation: 0.555
# epochs:  18 loss:  4.815135267276064 accuracy_train: 0.631 loss_val 5.812786576061355 accuracy_validation: 0.552
# epochs:  19 loss:  4.494178469971898 accuracy_train: 0.654 loss_val 5.488644092838674 accuracy_validation: 0.589
# epochs:  20 loss:  4.324603369448447 accuracy_train: 0.669 loss_val 5.231945204898486 accuracy_validation: 0.609
# epochs:  21 loss:  4.03899448769584 accuracy_train: 0.691 loss_val 5.0162869534112176 accuracy_validation: 0.622
# epochs:  22 loss:  3.801647766957418 accuracy_train: 0.704 loss_val 4.726981241985593 accuracy_validation: 0.645
# epochs:  23 loss:  3.4363183210343253 accuracy_train: 0.736 loss_val 4.404353032294996 accuracy_validation: 0.665
# epochs:  24 loss:  3.083007095273308 accuracy_train: 0.76 loss_val 4.063297738857734 accuracy_validation: 0.692
# epochs:  25 loss:  2.8427208976998073 accuracy_train: 0.781 loss_val 3.910595936508059 accuracy_validation: 0.704
# epochs:  26 loss:  2.7799013615067207 accuracy_train: 0.787 loss_val 3.958607569978125 accuracy_validation: 0.704
# epochs:  27 loss:  2.95182092108945 accuracy_train: 0.775 loss_val 4.000872316665367 accuracy_validation: 0.697
# epochs:  28 loss:  2.7125966420805336 accuracy_train: 0.79 loss_val 4.003294707157655 accuracy_validation: 0.701
# epochs:  29 loss:  2.8490284383880153 accuracy_train: 0.781 loss_val 3.8658887363028507 accuracy_validation: 0.706
# train (2.8490284383880153, 0.781)
# val (3.8658887363028507, 0.706)
# test (4.462710486422059, 0.6646)

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 4, l_rate = 0.01)
pool1 = MaxPoolingLayer(2)
CNN2 = Convolutional(input_shape = (4,13,13), kernel_size = 3,output_depth = 8, l_rate = 0.01)
pool2 = MaxPoolingLayer(2)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[288,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.01) # 8*6*6 = 288
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 64, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# epochs:  0 loss:  12.945514828991788 accuracy_train: 0.049 loss_val 12.875484006845793 accuracy_validation: 0.056
# epochs:  1 loss:  12.418265626335518 accuracy_train: 0.085 loss_val 12.076177517288528 accuracy_validation: 0.107
# epochs:  2 loss:  12.178571778347916 accuracy_train: 0.101 loss_val 11.71297202946203 accuracy_validation: 0.128
# epochs:  3 loss:  12.128505878641512 accuracy_train: 0.102 loss_val 11.667318321510868 accuracy_validation: 0.133
# epochs:  4 loss:  12.056057638573018 accuracy_train: 0.108 loss_val 11.621547000312715 accuracy_validation: 0.135
# epochs:  5 loss:  12.002376529282502 accuracy_train: 0.11 loss_val 11.56645666092823 accuracy_validation: 0.138
# epochs:  6 loss:  11.944207318352325 accuracy_train: 0.116 loss_val 11.490579286017761 accuracy_validation: 0.143
# epochs:  7 loss:  11.890819607250172 accuracy_train: 0.117 loss_val 11.427791835259653 accuracy_validation: 0.145
# epochs:  8 loss:  11.826548835664648 accuracy_train: 0.123 loss_val 11.349872392719742 accuracy_validation: 0.154
# epochs:  9 loss:  11.74184035037535 accuracy_train: 0.127 loss_val 11.266097955669046 accuracy_validation: 0.16
# epochs:  10 loss:  11.633359529914026 accuracy_train: 0.132 loss_val 11.195558878215591 accuracy_validation: 0.166
# epochs:  11 loss:  11.541138817924608 accuracy_train: 0.136 loss_val 11.139429955193929 accuracy_validation: 0.172
# epochs:  12 loss:  11.445316258331951 accuracy_train: 0.141 loss_val 11.088752127456148 accuracy_validation: 0.173
# epochs:  13 loss:  11.356122778972283 accuracy_train: 0.147 loss_val 11.049358796187306 accuracy_validation: 0.177
# epochs:  14 loss:  11.276327827937795 accuracy_train: 0.153 loss_val 10.988347529533154 accuracy_validation: 0.178
# epochs:  15 loss:  11.182783860704365 accuracy_train: 0.159 loss_val 10.912278931151956 accuracy_validation: 0.181
# epochs:  16 loss:  11.09166351225848 accuracy_train: 0.164 loss_val 10.840174668014265 accuracy_validation: 0.186
# epochs:  17 loss:  11.008352388502624 accuracy_train: 0.168 loss_val 10.777713118537129 accuracy_validation: 0.195
# epochs:  18 loss:  10.932928898531035 accuracy_train: 0.173 loss_val 10.706915075410583 accuracy_validation: 0.2
# epochs:  19 loss:  10.851101778043182 accuracy_train: 0.175 loss_val 10.612143486097 accuracy_validation: 0.205
# epochs:  20 loss:  10.77668986887095 accuracy_train: 0.178 loss_val 10.508439748758674 accuracy_validation: 0.205
# epochs:  21 loss:  10.70891610395733 accuracy_train: 0.187 loss_val 10.443485609358415 accuracy_validation: 0.209
# epochs:  22 loss:  10.636569440828824 accuracy_train: 0.188 loss_val 10.37897583292292 accuracy_validation: 0.213
# epochs:  23 loss:  10.54182238013288 accuracy_train: 0.195 loss_val 10.285797051429668 accuracy_validation: 0.223
# epochs:  24 loss:  10.458955891638658 accuracy_train: 0.203 loss_val 10.226708019650538 accuracy_validation: 0.226
# epochs:  25 loss:  10.367403297315034 accuracy_train: 0.21 loss_val 10.13444556482121 accuracy_validation: 0.234
# epochs:  26 loss:  10.281873459351416 accuracy_train: 0.214 loss_val 10.051727156985935 accuracy_validation: 0.236
# epochs:  27 loss:  10.193593652894267 accuracy_train: 0.216 loss_val 9.985701373203828 accuracy_validation: 0.244
# epochs:  28 loss:  10.111411369860729 accuracy_train: 0.222 loss_val 9.945173656751905 accuracy_validation: 0.244
# epochs:  29 loss:  10.043444278764973 accuracy_train: 0.229 loss_val 9.909634502601966 accuracy_validation: 0.243
# train (10.043444278764973, 0.229)
# val (9.909634502601966, 0.243)
# test (10.33382751708399, 0.219)

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 4, l_rate = 0.05)
pool1 = MaxPoolingLayer(2)
CNN2 = Convolutional(input_shape = (4,13,13), kernel_size = 3,output_depth = 8, l_rate = 0.05)
pool2 = MaxPoolingLayer(2)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[288,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.05) # 8*6*6 = 288
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 64, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# epochs:  0 loss:  11.273579564171403 accuracy_train: 0.164 loss_val 11.197473748747386 accuracy_validation: 0.17
# epochs:  1 loss:  10.159995448931479 accuracy_train: 0.241 loss_val 9.947346294482044 accuracy_validation: 0.26
# epochs:  2 loss:  9.462750265419768 accuracy_train: 0.282 loss_val 9.06265451114614 accuracy_validation: 0.32
# epochs:  3 loss:  8.775746814897056 accuracy_train: 0.342 loss_val 8.4630828336207 accuracy_validation: 0.369
# epochs:  4 loss:  8.217644568360516 accuracy_train: 0.367 loss_val 7.80425500498414 accuracy_validation: 0.404
# epochs:  5 loss:  7.82364187952554 accuracy_train: 0.405 loss_val 7.157757509126609 accuracy_validation: 0.458
# epochs:  6 loss:  7.577095259312416 accuracy_train: 0.422 loss_val 6.826266534206307 accuracy_validation: 0.479
# epochs:  7 loss:  7.2446493065597375 accuracy_train: 0.44 loss_val 6.714115596303232 accuracy_validation: 0.488
# epochs:  8 loss:  6.899742180924966 accuracy_train: 0.465 loss_val 6.581230854798265 accuracy_validation: 0.496
# epochs:  9 loss:  6.640177834671851 accuracy_train: 0.486 loss_val 6.275029493069045 accuracy_validation: 0.522
# epochs:  10 loss:  6.384012611266761 accuracy_train: 0.508 loss_val 6.03778926393572 accuracy_validation: 0.535
# epochs:  11 loss:  6.0808869965971315 accuracy_train: 0.53 loss_val 5.736223560156074 accuracy_validation: 0.554
# epochs:  12 loss:  5.907513968608964 accuracy_train: 0.541 loss_val 5.609084816091237 accuracy_validation: 0.571
# epochs:  13 loss:  5.649813703907925 accuracy_train: 0.558 loss_val 5.557681356472996 accuracy_validation: 0.576
# epochs:  14 loss:  5.469898015632792 accuracy_train: 0.568 loss_val 5.561707248589946 accuracy_validation: 0.579
# epochs:  15 loss:  5.255362700445268 accuracy_train: 0.592 loss_val 5.4531488311224505 accuracy_validation: 0.584
# epochs:  16 loss:  5.19580429573303 accuracy_train: 0.599 loss_val 5.364751354785167 accuracy_validation: 0.59
# epochs:  17 loss:  5.146224276746394 accuracy_train: 0.603 loss_val 5.341888607545718 accuracy_validation: 0.596
# epochs:  18 loss:  5.155552630174784 accuracy_train: 0.603 loss_val 5.2759644456196515 accuracy_validation: 0.601
# epochs:  19 loss:  5.188356048262682 accuracy_train: 0.601 loss_val 5.264989781103805 accuracy_validation: 0.601
# epochs:  20 loss:  5.096787641973393 accuracy_train: 0.602 loss_val 5.163941319752776 accuracy_validation: 0.602
# epochs:  21 loss:  4.976447830249448 accuracy_train: 0.612 loss_val 5.1371386885792365 accuracy_validation: 0.609
# epochs:  22 loss:  4.763268261419248 accuracy_train: 0.628 loss_val 4.886045856911631 accuracy_validation: 0.619
# epochs:  23 loss:  4.836531714340419 accuracy_train: 0.634 loss_val 4.885513166160372 accuracy_validation: 0.627
# epochs:  24 loss:  4.619780762450071 accuracy_train: 0.643 loss_val 4.695042080538764 accuracy_validation: 0.644
# epochs:  25 loss:  4.189211792599369 accuracy_train: 0.675 loss_val 4.228233265837604 accuracy_validation: 0.679
# epochs:  26 loss:  4.083971010470864 accuracy_train: 0.68 loss_val 4.087197605207126 accuracy_validation: 0.685
# epochs:  27 loss:  3.919466266140077 accuracy_train: 0.694 loss_val 3.9647360696098524 accuracy_validation: 0.696
# epochs:  28 loss:  4.122623034347292 accuracy_train: 0.683 loss_val 4.0309823587458835 accuracy_validation: 0.689
# epochs:  29 loss:  3.8473910849548503 accuracy_train: 0.701 loss_val 3.7903420919739452 accuracy_validation: 0.714
# train (3.8473910849548503, 0.701)
# val (3.7903420919739452, 0.714)
# test (4.484686502904656, 0.6584)

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 4, l_rate = 0.1)
pool1 = MaxPoolingLayer(2)
CNN2 = Convolutional(input_shape = (4,13,13), kernel_size = 3,output_depth = 8, l_rate = 0.1)
pool2 = MaxPoolingLayer(2)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[288,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.1) # 8*6*6 = 288
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 128, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# epochs:  0 loss:  11.35747305610125 accuracy_train: 0.162 loss_val 10.883044343147146 accuracy_validation: 0.192
# epochs:  1 loss:  10.636766494002158 accuracy_train: 0.208 loss_val 10.19358800589211 accuracy_validation: 0.235
# epochs:  2 loss:  10.014292432273733 accuracy_train: 0.244 loss_val 9.574396179961344 accuracy_validation: 0.281
# epochs:  3 loss:  9.592261532167402 accuracy_train: 0.276 loss_val 8.905487411358088 accuracy_validation: 0.325
# epochs:  4 loss:  9.051523479521325 accuracy_train: 0.313 loss_val 8.449341176233714 accuracy_validation: 0.365
# epochs:  5 loss:  8.685480259534994 accuracy_train: 0.333 loss_val 8.042911006261354 accuracy_validation: 0.383
# epochs:  6 loss:  7.993671211613547 accuracy_train: 0.393 loss_val 7.487472852511667 accuracy_validation: 0.422
# epochs:  7 loss:  7.356879597267034 accuracy_train: 0.423 loss_val 7.123381140639379 accuracy_validation: 0.457
# epochs:  8 loss:  7.375647738431376 accuracy_train: 0.432 loss_val 7.018971204579058 accuracy_validation: 0.456
# epochs:  9 loss:  6.857482122183965 accuracy_train: 0.467 loss_val 6.410885221354038 accuracy_validation: 0.501
# epochs:  10 loss:  6.449952386508958 accuracy_train: 0.5 loss_val 6.2119267579728765 accuracy_validation: 0.516
# epochs:  11 loss:  5.868541441093595 accuracy_train: 0.533 loss_val 5.841221131120776 accuracy_validation: 0.55
# epochs:  12 loss:  5.547143509274007 accuracy_train: 0.568 loss_val 5.631703195296848 accuracy_validation: 0.56
# epochs:  13 loss:  5.357464993408752 accuracy_train: 0.582 loss_val 5.295794599153273 accuracy_validation: 0.58
# epochs:  14 loss:  5.025155772445322 accuracy_train: 0.606 loss_val 4.890520145634009 accuracy_validation: 0.614
# epochs:  15 loss:  4.7912711942367014 accuracy_train: 0.625 loss_val 4.646631490087907 accuracy_validation: 0.643
# epochs:  16 loss:  4.533008387809068 accuracy_train: 0.644 loss_val 4.517189275360898 accuracy_validation: 0.643
# epochs:  17 loss:  4.440536022653597 accuracy_train: 0.652 loss_val 4.489419759783707 accuracy_validation: 0.646
# epochs:  18 loss:  4.0628751094210935 accuracy_train: 0.684 loss_val 4.263892522519679 accuracy_validation: 0.662
# epochs:  19 loss:  3.8575784844340317 accuracy_train: 0.691 loss_val 4.112524113531006 accuracy_validation: 0.682
# epochs:  20 loss:  3.7975164113360895 accuracy_train: 0.696 loss_val 4.002483981698828 accuracy_validation: 0.691
# epochs:  21 loss:  3.759725819140368 accuracy_train: 0.709 loss_val 3.9337674089383743 accuracy_validation: 0.697
# epochs:  22 loss:  3.6285931095635604 accuracy_train: 0.724 loss_val 3.888370124641377 accuracy_validation: 0.705
# epochs:  23 loss:  3.5505152739247445 accuracy_train: 0.726 loss_val 3.7468532445625997 accuracy_validation: 0.706
# epochs:  24 loss:  3.423775141811825 accuracy_train: 0.739 loss_val 3.649816957979453 accuracy_validation: 0.717
# epochs:  25 loss:  3.3919902372211324 accuracy_train: 0.735 loss_val 3.592650408025579 accuracy_validation: 0.719
# epochs:  26 loss:  3.304164378186606 accuracy_train: 0.741 loss_val 3.5775895802453026 accuracy_validation: 0.72
# epochs:  27 loss:  3.268239991522116 accuracy_train: 0.744 loss_val 3.4291606113798685 accuracy_validation: 0.733
# epochs:  28 loss:  3.185495171730072 accuracy_train: 0.75 loss_val 3.3566688307119104 accuracy_validation: 0.737
# epochs:  29 loss:  3.1548291636864985 accuracy_train: 0.753 loss_val 3.3136824082770153 accuracy_validation: 0.742
# train (3.1548291636864985, 0.753)
# val (3.3136824082770153, 0.742)
# test (4.501947505520559, 0.6556)

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 4, l_rate = 0.1)
pool1 = MaxPoolingLayer(2)
CNN2 = Convolutional(input_shape = (4,13,13), kernel_size = 3,output_depth = 8, l_rate = 0.1)
pool2 = MaxPoolingLayer(2)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[288,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.1) # 8*6*6 = 288
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# epochs:  0 loss:  11.176321611352343 accuracy_train: 0.175 loss_val 11.537028385770416 accuracy_validation: 0.155
# epochs:  1 loss:  8.845212003801928 accuracy_train: 0.34 loss_val 9.197431199389458 accuracy_validation: 0.315
# epochs:  2 loss:  7.888403679427538 accuracy_train: 0.408 loss_val 8.09274448849503 accuracy_validation: 0.394
# epochs:  3 loss:  6.869441033561396 accuracy_train: 0.469 loss_val 7.465163444167911 accuracy_validation: 0.428
# epochs:  4 loss:  5.9011407302878744 accuracy_train: 0.539 loss_val 6.124652975307718 accuracy_validation: 0.529
# epochs:  5 loss:  5.003682786184902 accuracy_train: 0.613 loss_val 5.30143249410775 accuracy_validation: 0.585
# epochs:  6 loss:  4.7490523950247425 accuracy_train: 0.632 loss_val 5.4495930102298304 accuracy_validation: 0.576
# epochs:  7 loss:  4.140158694758045 accuracy_train: 0.679 loss_val 4.730702651802258 accuracy_validation: 0.639
# epochs:  8 loss:  3.7896025493089502 accuracy_train: 0.697 loss_val 4.496179816042218 accuracy_validation: 0.656
# epochs:  9 loss:  3.6931725862206197 accuracy_train: 0.711 loss_val 4.306984285274053 accuracy_validation: 0.663
# epochs:  10 loss:  3.75041060536176 accuracy_train: 0.709 loss_val 4.362695687106681 accuracy_validation: 0.667
# epochs:  11 loss:  3.3769256072810334 accuracy_train: 0.732 loss_val 3.9928348515130136 accuracy_validation: 0.694
# epochs:  12 loss:  3.8315372367759997 accuracy_train: 0.699 loss_val 4.354311587761825 accuracy_validation: 0.67
# epochs:  13 loss:  2.9877861843826925 accuracy_train: 0.77 loss_val 3.768599070398308 accuracy_validation: 0.716
# epochs:  14 loss:  4.626083595645519 accuracy_train: 0.648 loss_val 5.274161719960174 accuracy_validation: 0.601
# epochs:  15 loss:  3.4792393069425698 accuracy_train: 0.733 loss_val 3.8727396219805956 accuracy_validation: 0.703
# epochs:  16 loss:  2.920727978087108 accuracy_train: 0.775 loss_val 3.7272509901057918 accuracy_validation: 0.714
# epochs:  17 loss:  3.797503575863462 accuracy_train: 0.712 loss_val 4.761233639667059 accuracy_validation: 0.637
# epochs:  18 loss:  3.4426509419202422 accuracy_train: 0.732 loss_val 3.823563548933339 accuracy_validation: 0.712
# epochs:  19 loss:  3.043125494717514 accuracy_train: 0.771 loss_val 3.487497386734768 accuracy_validation: 0.733
# epochs:  20 loss:  3.0625162193149635 accuracy_train: 0.766 loss_val 4.041215498429626 accuracy_validation: 0.699
# epochs:  21 loss:  3.023897837326188 accuracy_train: 0.768 loss_val 3.94388261086504 accuracy_validation: 0.702
# epochs:  22 loss:  2.309061846525461 accuracy_train: 0.818 loss_val 3.4642550609006992 accuracy_validation: 0.736
# epochs:  23 loss:  2.3806287614270456 accuracy_train: 0.813 loss_val 3.288082759538541 accuracy_validation: 0.751
# epochs:  24 loss:  2.165240343580833 accuracy_train: 0.832 loss_val 3.187315242403379 accuracy_validation: 0.762
# epochs:  25 loss:  2.9092794044397507 accuracy_train: 0.778 loss_val 3.941954639642475 accuracy_validation: 0.702
# epochs:  26 loss:  2.20131844154136 accuracy_train: 0.828 loss_val 3.435338482238035 accuracy_validation: 0.742
# epochs:  27 loss:  1.8701529535638117 accuracy_train: 0.855 loss_val 3.0501116533775794 accuracy_validation: 0.773
# epochs:  28 loss:  2.4199087806916335 accuracy_train: 0.816 loss_val 3.6592436939782558 accuracy_validation: 0.731
# epochs:  29 loss:  1.8664847784565426 accuracy_train: 0.855 loss_val 3.1006015160913276 accuracy_validation: 0.771
# train (1.8664847784565426, 0.855)
# val (3.1006015160913276, 0.771)
# test (3.49860193319437, 0.7385)

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 2, l_rate = 0.05)
pool1 = MaxPoolingLayer(2)
CNN2 = Convolutional(input_shape = (2,13,13), kernel_size = 3,output_depth = 4, l_rate = 0.05)
pool2 = MaxPoolingLayer(2)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[144,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.05) # 4*6*6 = 144
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 64, epochs = 60)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# epochs:  0 loss_train:  11.551354560687725 accuracy_train: 0.101 loss_val 11.62197667899423 accuracy_validation: 0.095
# epochs:  1 loss_train:  11.413862173843125 accuracy_train: 0.11 loss_val 11.485636372062421 accuracy_validation: 0.101
# epochs:  2 loss_train:  11.155235848235833 accuracy_train: 0.122 loss_val 11.294037206675615 accuracy_validation: 0.113
# epochs:  3 loss_train:  10.892032160195114 accuracy_train: 0.131 loss_val 11.062313870616169 accuracy_validation: 0.12
# epochs:  4 loss_train:  10.612913382051326 accuracy_train: 0.145 loss_val 10.848210984174953 accuracy_validation: 0.137
# epochs:  5 loss_train:  10.366408270378091 accuracy_train: 0.162 loss_val 10.664110569727677 accuracy_validation: 0.144
# epochs:  6 loss_train:  10.121547796287707 accuracy_train: 0.183 loss_val 10.464875920677583 accuracy_validation: 0.157
# epochs:  7 loss_train:  9.814464466340619 accuracy_train: 0.191 loss_val 10.20211868939534 accuracy_validation: 0.175
# epochs:  8 loss_train:  9.538529121977973 accuracy_train: 0.215 loss_val 9.935773697773339 accuracy_validation: 0.191
# epochs:  9 loss_train:  9.291435119113306 accuracy_train: 0.237 loss_val 9.633753362965322 accuracy_validation: 0.206
# epochs:  10 loss_train:  8.95125644812012 accuracy_train: 0.257 loss_val 9.317896580409222 accuracy_validation: 0.233
# epochs:  11 loss_train:  8.623080226597807 accuracy_train: 0.289 loss_val 9.033554771008179 accuracy_validation: 0.256
# epochs:  12 loss_train:  8.33964732094205 accuracy_train: 0.303 loss_val 8.73541236449037 accuracy_validation: 0.276
# epochs:  13 loss_train:  8.085706225281106 accuracy_train: 0.323 loss_val 8.461821772601608 accuracy_validation: 0.289
# epochs:  14 loss_train:  7.841749935299893 accuracy_train: 0.352 loss_val 8.193262790685537 accuracy_validation: 0.309
# epochs:  15 loss_train:  7.58121421481685 accuracy_train: 0.366 loss_val 7.943308106457608 accuracy_validation: 0.333
# epochs:  16 loss_train:  7.286339563634051 accuracy_train: 0.384 loss_val 7.706810209788645 accuracy_validation: 0.354
# epochs:  17 loss_train:  7.032710738467176 accuracy_train: 0.406 loss_val 7.482556477450165 accuracy_validation: 0.372
# epochs:  18 loss_train:  6.753650515918685 accuracy_train: 0.425 loss_val 7.190787068013316 accuracy_validation: 0.389
# epochs:  19 loss_train:  6.520079417096957 accuracy_train: 0.454 loss_val 6.941790406158892 accuracy_validation: 0.407
# epochs:  20 loss_train:  6.3155155803087775 accuracy_train: 0.467 loss_val 6.7340007108220385 accuracy_validation: 0.435
# epochs:  21 loss_train:  6.113144407543173 accuracy_train: 0.48 loss_val 6.568885561635586 accuracy_validation: 0.444
# epochs:  22 loss_train:  5.915080466967849 accuracy_train: 0.49 loss_val 6.417349055670459 accuracy_validation: 0.46
# epochs:  23 loss_train:  5.7471620897981275 accuracy_train: 0.5 loss_val 6.290197907854738 accuracy_validation: 0.476
# epochs:  24 loss_train:  5.5966966245355865 accuracy_train: 0.518 loss_val 6.153468793386068 accuracy_validation: 0.487
# epochs:  25 loss_train:  5.45660051582969 accuracy_train: 0.531 loss_val 6.0170719597363975 accuracy_validation: 0.494
# epochs:  26 loss_train:  5.342469198484919 accuracy_train: 0.538 loss_val 5.8786181321066 accuracy_validation: 0.496
# epochs:  27 loss_train:  5.239386402347429 accuracy_train: 0.551 loss_val 5.726328334793172 accuracy_validation: 0.51
# epochs:  28 loss_train:  5.14583303829949 accuracy_train: 0.559 loss_val 5.591625690676982 accuracy_validation: 0.524
# epochs:  29 loss_train:  5.035319838374699 accuracy_train: 0.569 loss_val 5.420067650434723 accuracy_validation: 0.538
# epochs:  30 loss_train:  4.915854673560052 accuracy_train: 0.583 loss_val 5.290364748477177 accuracy_validation: 0.555
# epochs:  31 loss_train:  4.826129867372923 accuracy_train: 0.592 loss_val 5.204208936025342 accuracy_validation: 0.568
# epochs:  32 loss_train:  4.722068506088442 accuracy_train: 0.601 loss_val 5.096857956468906 accuracy_validation: 0.578
# epochs:  33 loss_train:  4.663688440223654 accuracy_train: 0.605 loss_val 5.028431668171018 accuracy_validation: 0.592
# epochs:  34 loss_train:  4.585132819604585 accuracy_train: 0.612 loss_val 4.970220556582675 accuracy_validation: 0.601
# epochs:  35 loss_train:  4.4827176847751975 accuracy_train: 0.624 loss_val 4.874283222993431 accuracy_validation: 0.605
# epochs:  36 loss_train:  4.374922307512478 accuracy_train: 0.637 loss_val 4.72776522756164 accuracy_validation: 0.617
# epochs:  37 loss_train:  4.300692178309342 accuracy_train: 0.648 loss_val 4.578818027658262 accuracy_validation: 0.632
# epochs:  38 loss_train:  4.1985741533312115 accuracy_train: 0.648 loss_val 4.505421962555914 accuracy_validation: 0.629
# epochs:  39 loss_train:  4.126509961960303 accuracy_train: 0.656 loss_val 4.413121196731417 accuracy_validation: 0.64
# epochs:  40 loss_train:  4.031974595421678 accuracy_train: 0.66 loss_val 4.329777082210051 accuracy_validation: 0.651
# epochs:  41 loss_train:  3.952510434363189 accuracy_train: 0.666 loss_val 4.255443190465127 accuracy_validation: 0.657
# epochs:  42 loss_train:  3.895249385693252 accuracy_train: 0.674 loss_val 4.225500792614685 accuracy_validation: 0.658
# epochs:  43 loss_train:  3.8851003989494175 accuracy_train: 0.668 loss_val 4.193843352544745 accuracy_validation: 0.657
# epochs:  44 loss_train:  3.8421466046500936 accuracy_train: 0.68 loss_val 4.117597434612335 accuracy_validation: 0.662
# epochs:  45 loss_train:  3.733693399611491 accuracy_train: 0.681 loss_val 4.009745172014183 accuracy_validation: 0.671
# epochs:  46 loss_train:  3.6118094669306466 accuracy_train: 0.694 loss_val 3.9143550901205777 accuracy_validation: 0.679
# epochs:  47 loss_train:  3.5143224547503538 accuracy_train: 0.71 loss_val 3.817464453344046 accuracy_validation: 0.681
# epochs:  48 loss_train:  3.452175748852628 accuracy_train: 0.716 loss_val 3.7672601612448418 accuracy_validation: 0.689
# epochs:  49 loss_train:  3.3870468577800894 accuracy_train: 0.722 loss_val 3.701614453043153 accuracy_validation: 0.696
# epochs:  50 loss_train:  3.3007079218458237 accuracy_train: 0.723 loss_val 3.656494883076525 accuracy_validation: 0.706
# epochs:  51 loss_train:  3.2549022225601374 accuracy_train: 0.727 loss_val 3.6262905977586892 accuracy_validation: 0.711
# epochs:  52 loss_train:  3.212584187833947 accuracy_train: 0.732 loss_val 3.608267899676087 accuracy_validation: 0.713
# epochs:  53 loss_train:  3.150432430654706 accuracy_train: 0.736 loss_val 3.581006386222174 accuracy_validation: 0.718
# epochs:  54 loss_train:  3.099899520469463 accuracy_train: 0.739 loss_val 3.548695027674316 accuracy_validation: 0.721
# epochs:  55 loss_train:  3.05046315512728 accuracy_train: 0.745 loss_val 3.5037524708759786 accuracy_validation: 0.718
# epochs:  56 loss_train:  3.0197861328934477 accuracy_train: 0.748 loss_val 3.456443522164754 accuracy_validation: 0.724
# epochs:  57 loss_train:  2.970462345692038 accuracy_train: 0.756 loss_val 3.418427358966697 accuracy_validation: 0.728
# epochs:  58 loss_train:  2.9339734893178693 accuracy_train: 0.755 loss_val 3.4022471349058234 accuracy_validation: 0.734
# epochs:  59 loss_train:  2.899539820835339 accuracy_train: 0.753 loss_val 3.401003515823936 accuracy_validation: 0.733
# train (2.899539820835339, 0.753)
# val (3.401003515823936, 0.733)
# test (4.016857683262626, 0.6764)

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 2, l_rate = 0.1)
pool1 = MaxPoolingLayer(2)
CNN2 = Convolutional(input_shape = (2,13,13), kernel_size = 3,output_depth = 4, l_rate = 0.1)
pool2 = MaxPoolingLayer(2)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[144,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.1) # 4*6*6 = 144
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 64, epochs = 60)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# epochs:  0 loss_train:  12.073371458206463 accuracy_train: 0.088 loss_val 12.11369123637951 accuracy_validation: 0.088
# epochs:  1 loss_train:  11.293754539161922 accuracy_train: 0.133 loss_val 11.278177646098998 accuracy_validation: 0.143
# epochs:  2 loss_train:  10.35084334073871 accuracy_train: 0.185 loss_val 10.424042409964768 accuracy_validation: 0.187
# epochs:  3 loss_train:  9.451811610908038 accuracy_train: 0.261 loss_val 9.547346461801824 accuracy_validation: 0.25
# epochs:  4 loss_train:  9.052903654401835 accuracy_train: 0.275 loss_val 8.981971364037097 accuracy_validation: 0.283
# epochs:  5 loss_train:  8.53918112293597 accuracy_train: 0.324 loss_val 8.411663753558372 accuracy_validation: 0.325
# epochs:  6 loss_train:  7.880475813322717 accuracy_train: 0.367 loss_val 7.737966769290079 accuracy_validation: 0.386
# epochs:  7 loss_train:  7.208189789081615 accuracy_train: 0.419 loss_val 7.180039494769181 accuracy_validation: 0.419
# epochs:  8 loss_train:  6.800340996687772 accuracy_train: 0.45 loss_val 6.949540449254885 accuracy_validation: 0.442
# epochs:  9 loss_train:  6.421522386621093 accuracy_train: 0.488 loss_val 6.617440349306535 accuracy_validation: 0.471
# epochs:  10 loss_train:  6.049004969400282 accuracy_train: 0.507 loss_val 6.124635282771049 accuracy_validation: 0.506
# epochs:  11 loss_train:  5.759017400496463 accuracy_train: 0.53 loss_val 5.930240696676419 accuracy_validation: 0.523
# epochs:  12 loss_train:  5.340489158163034 accuracy_train: 0.567 loss_val 5.596467902081286 accuracy_validation: 0.549
# epochs:  13 loss_train:  5.016001334669134 accuracy_train: 0.591 loss_val 5.260468845926701 accuracy_validation: 0.578
# epochs:  14 loss_train:  4.776805551577869 accuracy_train: 0.62 loss_val 4.9882929122809445 accuracy_validation: 0.597
# epochs:  15 loss_train:  4.628470184487376 accuracy_train: 0.634 loss_val 4.836066178375384 accuracy_validation: 0.615
# epochs:  16 loss_train:  4.397525809515077 accuracy_train: 0.644 loss_val 4.5824790520872645 accuracy_validation: 0.631
# epochs:  17 loss_train:  4.123054325904955 accuracy_train: 0.667 loss_val 4.290374763492888 accuracy_validation: 0.652
# epochs:  18 loss_train:  3.952218330642387 accuracy_train: 0.676 loss_val 4.285264373968483 accuracy_validation: 0.657
# epochs:  19 loss_train:  3.9436605983959825 accuracy_train: 0.681 loss_val 4.261593565775063 accuracy_validation: 0.659
# epochs:  20 loss_train:  3.962330247916745 accuracy_train: 0.681 loss_val 4.235379509223915 accuracy_validation: 0.66
# epochs:  21 loss_train:  3.845981529708418 accuracy_train: 0.683 loss_val 4.174441940813067 accuracy_validation: 0.669
# epochs:  22 loss_train:  3.8072217070069128 accuracy_train: 0.691 loss_val 4.096782203552003 accuracy_validation: 0.672
# epochs:  23 loss_train:  3.7553106012610877 accuracy_train: 0.694 loss_val 4.030477010007203 accuracy_validation: 0.675
# epochs:  24 loss_train:  3.676429834159454 accuracy_train: 0.697 loss_val 4.022763961695023 accuracy_validation: 0.677
# epochs:  25 loss_train:  3.566058168707834 accuracy_train: 0.714 loss_val 3.9149687103130146 accuracy_validation: 0.683
# epochs:  26 loss_train:  3.522543138508969 accuracy_train: 0.711 loss_val 3.8442754621334854 accuracy_validation: 0.698
# epochs:  27 loss_train:  3.286615415508186 accuracy_train: 0.724 loss_val 3.7960943974024115 accuracy_validation: 0.703
# epochs:  28 loss_train:  3.1563748788328945 accuracy_train: 0.737 loss_val 3.719410869598548 accuracy_validation: 0.706
# epochs:  29 loss_train:  3.1954230003494604 accuracy_train: 0.738 loss_val 3.6765856144427116 accuracy_validation: 0.709
# epochs:  30 loss_train:  2.9873464931121174 accuracy_train: 0.744 loss_val 3.5924971158112355 accuracy_validation: 0.711
# epochs:  31 loss_train:  2.914511481999896 accuracy_train: 0.755 loss_val 3.5020757022303033 accuracy_validation: 0.725
# epochs:  32 loss_train:  3.000285284950109 accuracy_train: 0.754 loss_val 3.3847481904429237 accuracy_validation: 0.735
# epochs:  33 loss_train:  2.8258031904075795 accuracy_train: 0.766 loss_val 3.3478343005012334 accuracy_validation: 0.73
# epochs:  34 loss_train:  2.901178341894729 accuracy_train: 0.761 loss_val 3.2358252250610007 accuracy_validation: 0.736
# epochs:  35 loss_train:  2.5529552148538546 accuracy_train: 0.791 loss_val 3.1219649471491167 accuracy_validation: 0.748
# epochs:  36 loss_train:  2.4673664212970725 accuracy_train: 0.791 loss_val 3.146109256792416 accuracy_validation: 0.752
# epochs:  37 loss_train:  2.5385541878957487 accuracy_train: 0.789 loss_val 3.0692664235878557 accuracy_validation: 0.753
# epochs:  38 loss_train:  2.5333283385231624 accuracy_train: 0.785 loss_val 3.166370094576977 accuracy_validation: 0.744
# epochs:  39 loss_train:  2.3567994478513024 accuracy_train: 0.803 loss_val 3.0669555401558966 accuracy_validation: 0.756
# epochs:  40 loss_train:  2.467328834932293 accuracy_train: 0.795 loss_val 3.0563468587857647 accuracy_validation: 0.76
# epochs:  41 loss_train:  2.3735182779896222 accuracy_train: 0.798 loss_val 3.079954167617934 accuracy_validation: 0.752
# epochs:  42 loss_train:  2.2674554366417636 accuracy_train: 0.795 loss_val 2.994310590965267 accuracy_validation: 0.762
# epochs:  43 loss_train:  2.1352410000742377 accuracy_train: 0.818 loss_val 2.8967638295670546 accuracy_validation: 0.768
# epochs:  44 loss_train:  2.0478231463520262 accuracy_train: 0.826 loss_val 2.8768319135691445 accuracy_validation: 0.77
# epochs:  45 loss_train:  1.9359968112626702 accuracy_train: 0.821 loss_val 2.824048656994905 accuracy_validation: 0.775
# epochs:  46 loss_train:  1.9081309574139322 accuracy_train: 0.825 loss_val 2.766796682656267 accuracy_validation: 0.773
# epochs:  47 loss_train:  1.8931504201772102 accuracy_train: 0.833 loss_val 2.7183732859016154 accuracy_validation: 0.781
# epochs:  48 loss_train:  1.7816993011561795 accuracy_train: 0.845 loss_val 2.715283536571746 accuracy_validation: 0.781
# epochs:  49 loss_train:  1.745569126072623 accuracy_train: 0.844 loss_val 2.751467940539176 accuracy_validation: 0.781
# epochs:  50 loss_train:  1.7150288833463418 accuracy_train: 0.849 loss_val 2.688495369938949 accuracy_validation: 0.781
# epochs:  51 loss_train:  1.749616032332613 accuracy_train: 0.844 loss_val 2.670069941884169 accuracy_validation: 0.79
# epochs:  52 loss_train:  1.6389448951463137 accuracy_train: 0.85 loss_val 2.620640968198172 accuracy_validation: 0.789
# epochs:  53 loss_train:  1.648693146897166 accuracy_train: 0.848 loss_val 2.671548629198875 accuracy_validation: 0.785
# epochs:  54 loss_train:  1.624021057745608 accuracy_train: 0.853 loss_val 2.7001438352108726 accuracy_validation: 0.783
# epochs:  55 loss_train:  1.5829573752003239 accuracy_train: 0.858 loss_val 2.7108901892303012 accuracy_validation: 0.783
# epochs:  56 loss_train:  1.513556225676108 accuracy_train: 0.868 loss_val 2.6763115880169135 accuracy_validation: 0.788
# epochs:  57 loss_train:  1.5470759359251973 accuracy_train: 0.863 loss_val 2.6028612255156967 accuracy_validation: 0.795
# epochs:  58 loss_train:  1.5831229293290645 accuracy_train: 0.862 loss_val 2.6810000876749664 accuracy_validation: 0.793
# epochs:  59 loss_train:  1.5629640540461456 accuracy_train: 0.87 loss_val 2.637805664337082 accuracy_validation: 0.794
# train (1.5629640540461456, 0.87)
# val (2.637805664337082, 0.794)
# test (3.4131942447534342, 0.729)

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 8, l_rate = 0.05)
pool1 = MaxPoolingLayer(2)
CNN2 = Convolutional(input_shape = (8,13,13), kernel_size = 3,output_depth = 16, l_rate = 0.05)
pool2 = MaxPoolingLayer(2)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[576,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.05) # 16*6*6 = 576
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 64, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# epochs:  0 loss_train:  11.777744620447542 accuracy_train: 0.137 loss_val 11.18614204462777 accuracy_validation: 0.182
# epochs:  1 loss_train:  9.834303108443406 accuracy_train: 0.282 loss_val 9.08836724523874 accuracy_validation: 0.329
# epochs:  2 loss_train:  9.28380166212426 accuracy_train: 0.317 loss_val 8.799335614717421 accuracy_validation: 0.349
# epochs:  3 loss_train:  8.499896398731698 accuracy_train: 0.373 loss_val 7.767293793576782 accuracy_validation: 0.427
# epochs:  4 loss_train:  7.4300606152195865 accuracy_train: 0.444 loss_val 7.079915083773203 accuracy_validation: 0.472
# epochs:  5 loss_train:  6.815473170707697 accuracy_train: 0.493 loss_val 6.4575122233647875 accuracy_validation: 0.518
# epochs:  6 loss_train:  6.343654845193098 accuracy_train: 0.526 loss_val 6.239367248951858 accuracy_validation: 0.539
# epochs:  7 loss_train:  5.893614969561423 accuracy_train: 0.562 loss_val 5.93478916820486 accuracy_validation: 0.564
# epochs:  8 loss_train:  5.639353431445346 accuracy_train: 0.584 loss_val 5.518483118027685 accuracy_validation: 0.589
# epochs:  9 loss_train:  5.2303230805102645 accuracy_train: 0.615 loss_val 5.15957431584529 accuracy_validation: 0.615
# epochs:  10 loss_train:  4.79092509988926 accuracy_train: 0.638 loss_val 4.953092873787408 accuracy_validation: 0.633
# epochs:  11 loss_train:  4.653650783448215 accuracy_train: 0.653 loss_val 4.707241765244691 accuracy_validation: 0.655
# epochs:  12 loss_train:  4.609661231686721 accuracy_train: 0.653 loss_val 4.831261052680955 accuracy_validation: 0.639
# epochs:  13 loss_train:  4.4366518736642115 accuracy_train: 0.667 loss_val 4.697095123393075 accuracy_validation: 0.65
# epochs:  14 loss_train:  3.994730076459953 accuracy_train: 0.698 loss_val 4.388958569147459 accuracy_validation: 0.673
# epochs:  15 loss_train:  3.812473381575675 accuracy_train: 0.71 loss_val 4.232933268132143 accuracy_validation: 0.686
# epochs:  16 loss_train:  3.959358775070862 accuracy_train: 0.703 loss_val 4.390429435749093 accuracy_validation: 0.672
# epochs:  17 loss_train:  3.588489863495935 accuracy_train: 0.729 loss_val 3.981537518655642 accuracy_validation: 0.705
# epochs:  18 loss_train:  3.7005765246368165 accuracy_train: 0.722 loss_val 3.9367638796855453 accuracy_validation: 0.708
# epochs:  19 loss_train:  3.7342883517291696 accuracy_train: 0.722 loss_val 4.013505791409772 accuracy_validation: 0.703
# epochs:  20 loss_train:  3.4637843656516147 accuracy_train: 0.741 loss_val 3.937744284035967 accuracy_validation: 0.712
# epochs:  21 loss_train:  3.1978110697053834 accuracy_train: 0.764 loss_val 3.6616377976689205 accuracy_validation: 0.729
# epochs:  22 loss_train:  3.1237442461168046 accuracy_train: 0.764 loss_val 3.6301384931250964 accuracy_validation: 0.73
# epochs:  23 loss_train:  2.933931413424856 accuracy_train: 0.78 loss_val 3.49180044999395 accuracy_validation: 0.741
# epochs:  24 loss_train:  3.230535610891193 accuracy_train: 0.761 loss_val 3.5871529382145693 accuracy_validation: 0.729
# epochs:  25 loss_train:  2.9013308605988004 accuracy_train: 0.784 loss_val 3.1742373937170676 accuracy_validation: 0.761
# epochs:  26 loss_train:  3.0170140585114464 accuracy_train: 0.775 loss_val 3.2745976074568004 accuracy_validation: 0.755
# epochs:  27 loss_train:  2.7918952585982395 accuracy_train: 0.791 loss_val 3.0613671072022104 accuracy_validation: 0.773
# epochs:  28 loss_train:  2.7215607201992724 accuracy_train: 0.798 loss_val 3.0182684915741294 accuracy_validation: 0.774
# epochs:  29 loss_train:  2.7261149923658654 accuracy_train: 0.794 loss_val 2.8997259091680254 accuracy_validation: 0.784
# train (2.7261149923658654, 0.794)
# val (2.8997259091680254, 0.784)
# test (4.008897150030433, 0.7038)

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 8, l_rate = 0.05)
pool1 = MaxPoolingLayer(3)
CNN2 = Convolutional(input_shape = (8,9,9), kernel_size = 3,output_depth = 16, l_rate = 0.05)
pool2 = MaxPoolingLayer(3)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[144,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.05) # 16*3*3 = 144
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 64, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# epochs:  0 loss_train:  11.975394187878798 accuracy_train: 0.117 loss_val 11.873683198026832 accuracy_validation: 0.119
# epochs:  1 loss_train:  11.481608112524846 accuracy_train: 0.144 loss_val 11.189164096949037 accuracy_validation: 0.162
# epochs:  2 loss_train:  11.067140473260947 accuracy_train: 0.167 loss_val 10.783582162631669 accuracy_validation: 0.191
# epochs:  3 loss_train:  10.811907614162289 accuracy_train: 0.184 loss_val 10.47600798618884 accuracy_validation: 0.208
# epochs:  4 loss_train:  10.506599433608867 accuracy_train: 0.199 loss_val 10.314662709789639 accuracy_validation: 0.221
# epochs:  5 loss_train:  10.266398783937143 accuracy_train: 0.226 loss_val 10.082087502761068 accuracy_validation: 0.23
# epochs:  6 loss_train:  9.875360388457969 accuracy_train: 0.245 loss_val 9.774601665583104 accuracy_validation: 0.255
# epochs:  7 loss_train:  9.46428628759502 accuracy_train: 0.278 loss_val 9.376025916871095 accuracy_validation: 0.281
# epochs:  8 loss_train:  9.227576061107213 accuracy_train: 0.294 loss_val 9.167425641993853 accuracy_validation: 0.294
# epochs:  9 loss_train:  8.801998142151511 accuracy_train: 0.32 loss_val 8.847934957837426 accuracy_validation: 0.326
# epochs:  10 loss_train:  8.555064740887923 accuracy_train: 0.335 loss_val 8.66219251803184 accuracy_validation: 0.333
# epochs:  11 loss_train:  8.307973244799214 accuracy_train: 0.344 loss_val 8.430813745497042 accuracy_validation: 0.348
# epochs:  12 loss_train:  8.170985554423458 accuracy_train: 0.359 loss_val 8.241173841510236 accuracy_validation: 0.358
# epochs:  13 loss_train:  7.779418881747423 accuracy_train: 0.383 loss_val 7.936888442117503 accuracy_validation: 0.386
# epochs:  14 loss_train:  7.584758336335974 accuracy_train: 0.406 loss_val 7.726994129361729 accuracy_validation: 0.401
# epochs:  15 loss_train:  7.325139185248786 accuracy_train: 0.425 loss_val 7.51880081449972 accuracy_validation: 0.416
# epochs:  16 loss_train:  7.176715028611055 accuracy_train: 0.439 loss_val 7.3059094765479555 accuracy_validation: 0.428
# epochs:  17 loss_train:  7.051621116457551 accuracy_train: 0.446 loss_val 7.209429808989652 accuracy_validation: 0.427
# epochs:  18 loss_train:  7.057278420554594 accuracy_train: 0.451 loss_val 7.2317387415023004 accuracy_validation: 0.432
# epochs:  19 loss_train:  6.774413203637045 accuracy_train: 0.473 loss_val 6.787297758911253 accuracy_validation: 0.467
# epochs:  20 loss_train:  6.6765628857140795 accuracy_train: 0.484 loss_val 6.673910412985102 accuracy_validation: 0.477
# epochs:  21 loss_train:  6.566512596072569 accuracy_train: 0.488 loss_val 6.524299827764189 accuracy_validation: 0.49
# epochs:  22 loss_train:  6.4860036281657685 accuracy_train: 0.494 loss_val 6.469118994596909 accuracy_validation: 0.491
# epochs:  23 loss_train:  6.413228029485137 accuracy_train: 0.504 loss_val 6.386264125543682 accuracy_validation: 0.497
# epochs:  24 loss_train:  6.448983456702844 accuracy_train: 0.495 loss_val 6.419753315909372 accuracy_validation: 0.495
# epochs:  25 loss_train:  6.298741441649601 accuracy_train: 0.508 loss_val 6.452944545537621 accuracy_validation: 0.491
# epochs:  26 loss_train:  6.2851508687411695 accuracy_train: 0.504 loss_val 6.297188276688847 accuracy_validation: 0.503
# epochs:  27 loss_train:  6.1081324415617315 accuracy_train: 0.516 loss_val 6.251381065479994 accuracy_validation: 0.518
# epochs:  28 loss_train:  6.177410603011342 accuracy_train: 0.511 loss_val 6.294873394330411 accuracy_validation: 0.514
# epochs:  29 loss_train:  6.102421477427696 accuracy_train: 0.518 loss_val 6.20661862959532 accuracy_validation: 0.515
# train (6.102421477427696, 0.518)
# val (6.20661862959532, 0.515)
# test (6.827478834285296, 0.4674)

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 4, l_rate = 0.1, activeFuncion="relu")
pool1 = MaxPoolingLayer(2)
CNN2 = Convolutional(input_shape = (4,13,13), kernel_size = 3,output_depth = 8, l_rate = 0.1, activeFuncion= "relu")
pool2 = MaxPoolingLayer(2)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[288,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.1) # 8*6*6 = 288
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# epochs:  0 loss_train:  9.712560999376157 accuracy_train: 0.202 loss_val 10.068041402366195 accuracy_validation: 0.192
# epochs:  1 loss_train:  8.78254228694242 accuracy_train: 0.234 loss_val 9.004342166163363 accuracy_validation: 0.228
# epochs:  2 loss_train:  8.455165641467381 accuracy_train: 0.285 loss_val 8.676271148196431 accuracy_validation: 0.265
# epochs:  3 loss_train:  7.616912554411565 accuracy_train: 0.296 loss_val 7.761393638121148 accuracy_validation: 0.287
# epochs:  4 loss_train:  7.165393695002411 accuracy_train: 0.328 loss_val 7.334779480003691 accuracy_validation: 0.316
# epochs:  5 loss_train:  6.8691103906638125 accuracy_train: 0.354 loss_val 7.101292078265198 accuracy_validation: 0.332
# epochs:  6 loss_train:  6.185723053534944 accuracy_train: 0.374 loss_val 6.2381245773521785 accuracy_validation: 0.383
# epochs:  7 loss_train:  5.951648207247887 accuracy_train: 0.396 loss_val 5.9772480238822165 accuracy_validation: 0.399
# epochs:  8 loss_train:  6.077947272187601 accuracy_train: 0.403 loss_val 6.038435817050164 accuracy_validation: 0.412
# epochs:  9 loss_train:  5.182979457035378 accuracy_train: 0.444 loss_val 5.207778400516059 accuracy_validation: 0.461
# epochs:  10 loss_train:  4.729053068331911 accuracy_train: 0.476 loss_val 4.760446945644045 accuracy_validation: 0.479
# epochs:  11 loss_train:  4.7424959097959976 accuracy_train: 0.483 loss_val 4.784427180880671 accuracy_validation: 0.486
# epochs:  12 loss_train:  4.227829933516296 accuracy_train: 0.504 loss_val 4.350711894000494 accuracy_validation: 0.516
# epochs:  13 loss_train:  3.997959133309655 accuracy_train: 0.514 loss_val 4.108675566985768 accuracy_validation: 0.529
# epochs:  14 loss_train:  4.140108763589337 accuracy_train: 0.519 loss_val 4.171761345915996 accuracy_validation: 0.526
# epochs:  15 loss_train:  3.5977542200179715 accuracy_train: 0.552 loss_val 3.845974670687102 accuracy_validation: 0.565
# epochs:  16 loss_train:  3.451283411682095 accuracy_train: 0.573 loss_val 3.701900947447927 accuracy_validation: 0.571
# epochs:  17 loss_train:  3.5198911399750537 accuracy_train: 0.587 loss_val 3.9037760119236027 accuracy_validation: 0.57
# epochs:  18 loss_train:  3.233175862840253 accuracy_train: 0.608 loss_val 3.5742084816256856 accuracy_validation: 0.588
# epochs:  19 loss_train:  3.1204212352054763 accuracy_train: 0.615 loss_val 3.4578464294518607 accuracy_validation: 0.599
# epochs:  20 loss_train:  3.1326851131850177 accuracy_train: 0.611 loss_val 3.4366469296801427 accuracy_validation: 0.599
# epochs:  21 loss_train:  2.9305405383021226 accuracy_train: 0.637 loss_val 3.2242271260207205 accuracy_validation: 0.611
# epochs:  22 loss_train:  2.8299274298140427 accuracy_train: 0.652 loss_val 3.1787577854347617 accuracy_validation: 0.628
# epochs:  23 loss_train:  3.0342861945918336 accuracy_train: 0.625 loss_val 3.299162868268735 accuracy_validation: 0.607
# epochs:  24 loss_train:  2.7812189321590624 accuracy_train: 0.665 loss_val 3.197820373762455 accuracy_validation: 0.64
# epochs:  25 loss_train:  2.6991725702061706 accuracy_train: 0.672 loss_val 3.1185767668360604 accuracy_validation: 0.645
# epochs:  26 loss_train:  2.8415619577526723 accuracy_train: 0.661 loss_val 3.2539493629108573 accuracy_validation: 0.648
# epochs:  27 loss_train:  2.72833280654593 accuracy_train: 0.682 loss_val 3.1626258487260044 accuracy_validation: 0.662
# epochs:  28 loss_train:  2.601800810801394 accuracy_train: 0.704 loss_val 3.1141901542212516 accuracy_validation: 0.668
# epochs:  29 loss_train:  2.650851917164023 accuracy_train: 0.69 loss_val 3.2081161759922967 accuracy_validation: 0.677
# train (2.650851917164023, 0.69)
# val (3.2081161759922967, 0.677)
# test (3.7778376079509792, 0.606)

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 4, l_rate = 0.05, activeFuncion="relu")
pool1 = MaxPoolingLayer(2)
CNN2 = Convolutional(input_shape = (4,13,13), kernel_size = 3,output_depth = 8, l_rate = 0.05, activeFuncion= "relu")
pool2 = MaxPoolingLayer(2)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[288,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.05) # 8*6*6 = 288
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# epochs:  0 loss_train:  11.308971137513538 accuracy_train: 0.129 loss_val 11.226981998984243 accuracy_validation: 0.138
# epochs:  1 loss_train:  10.652714234673516 accuracy_train: 0.159 loss_val 10.723876597105866 accuracy_validation: 0.169
# epochs:  2 loss_train:  10.01418720104124 accuracy_train: 0.193 loss_val 10.03638800051997 accuracy_validation: 0.203
# epochs:  3 loss_train:  8.807821051594583 accuracy_train: 0.279 loss_val 9.165923149230379 accuracy_validation: 0.269
# epochs:  4 loss_train:  8.047919502493949 accuracy_train: 0.316 loss_val 8.651201895099033 accuracy_validation: 0.297
# epochs:  5 loss_train:  7.786091477686483 accuracy_train: 0.356 loss_val 8.372014024229717 accuracy_validation: 0.312
# epochs:  6 loss_train:  7.218823954070207 accuracy_train: 0.379 loss_val 7.679203026500294 accuracy_validation: 0.355
# epochs:  7 loss_train:  6.859239050261386 accuracy_train: 0.407 loss_val 7.166273076278677 accuracy_validation: 0.386
# epochs:  8 loss_train:  6.597401202733946 accuracy_train: 0.44 loss_val 6.889376044160334 accuracy_validation: 0.41
# epochs:  9 loss_train:  6.272842851519409 accuracy_train: 0.459 loss_val 6.491202215299553 accuracy_validation: 0.434
# epochs:  10 loss_train:  5.880399038879418 accuracy_train: 0.474 loss_val 6.1291508815088225 accuracy_validation: 0.459
# epochs:  11 loss_train:  5.693813839085361 accuracy_train: 0.49 loss_val 5.950595524179604 accuracy_validation: 0.46
# epochs:  12 loss_train:  5.557928674090608 accuracy_train: 0.509 loss_val 5.8020933992419375 accuracy_validation: 0.478
# epochs:  13 loss_train:  5.427241714399595 accuracy_train: 0.516 loss_val 5.66740488181364 accuracy_validation: 0.492
# epochs:  14 loss_train:  5.027559141640317 accuracy_train: 0.54 loss_val 5.310712390756437 accuracy_validation: 0.514
# epochs:  15 loss_train:  5.048555647280044 accuracy_train: 0.536 loss_val 5.2845588659866936 accuracy_validation: 0.515
# epochs:  16 loss_train:  4.738038709244545 accuracy_train: 0.563 loss_val 4.9545322129399265 accuracy_validation: 0.542
# epochs:  17 loss_train:  4.688825381428067 accuracy_train: 0.564 loss_val 5.0073578240316525 accuracy_validation: 0.538
# epochs:  18 loss_train:  4.523740793363809 accuracy_train: 0.577 loss_val 4.7928304128931325 accuracy_validation: 0.566
# epochs:  19 loss_train:  4.38615571338279 accuracy_train: 0.594 loss_val 4.626558976145055 accuracy_validation: 0.574
# epochs:  20 loss_train:  4.433363920055783 accuracy_train: 0.583 loss_val 4.739202841732928 accuracy_validation: 0.562
# epochs:  21 loss_train:  4.2946229127070525 accuracy_train: 0.6 loss_val 4.562195436809694 accuracy_validation: 0.584
# epochs:  22 loss_train:  4.257844810726255 accuracy_train: 0.604 loss_val 4.488437192614875 accuracy_validation: 0.591
# epochs:  23 loss_train:  4.126965011487137 accuracy_train: 0.617 loss_val 4.520424449067707 accuracy_validation: 0.591
# epochs:  24 loss_train:  4.069017665792876 accuracy_train: 0.619 loss_val 4.4069390460006 accuracy_validation: 0.602
# epochs:  25 loss_train:  3.910908435244968 accuracy_train: 0.634 loss_val 4.26474357597826 accuracy_validation: 0.618
# epochs:  26 loss_train:  3.972109411213952 accuracy_train: 0.63 loss_val 4.3483816293030575 accuracy_validation: 0.614
# epochs:  27 loss_train:  3.9045248063567817 accuracy_train: 0.65 loss_val 4.183120481832447 accuracy_validation: 0.624
# epochs:  28 loss_train:  3.80989748785603 accuracy_train: 0.649 loss_val 4.09658403093854 accuracy_validation: 0.63
# epochs:  29 loss_train:  3.7848106485660407 accuracy_train: 0.648 loss_val 4.14651199166465 accuracy_validation: 0.627
# train (3.7848106485660407, 0.648)
# val (4.14651199166465, 0.627)
# test (4.861379487477044, 0.5635)

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 2, l_rate = 0.1, activeFuncion="relu")
pool1 = MaxPoolingLayer(2)
CNN2 = Convolutional(input_shape = (2,13,13), kernel_size = 3,output_depth = 4, l_rate = 0.1, activeFuncion= "relu")
pool2 = MaxPoolingLayer(2)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[144,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.1) # 4*6*6 = 144
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# epochs:  0 loss_train:  10.281229915914691 accuracy_train: 0.102 loss_val 10.304650900720533 accuracy_validation: 0.102
# epochs:  1 loss_train:  9.332275822109093 accuracy_train: 0.127 loss_val 9.338547985873785 accuracy_validation: 0.148
# epochs:  2 loss_train:  8.888184518941662 accuracy_train: 0.154 loss_val 8.873412403037289 accuracy_validation: 0.171
# epochs:  3 loss_train:  7.963524362637021 accuracy_train: 0.19 loss_val 7.973704535819568 accuracy_validation: 0.229
# epochs:  4 loss_train:  7.12684962306635 accuracy_train: 0.248 loss_val 7.212490952686479 accuracy_validation: 0.277
# epochs:  5 loss_train:  6.759486264588086 accuracy_train: 0.269 loss_val 6.8287477242110635 accuracy_validation: 0.291
# epochs:  6 loss_train:  6.208674709092744 accuracy_train: 0.321 loss_val 6.311400060085259 accuracy_validation: 0.322
# epochs:  7 loss_train:  5.827170932768128 accuracy_train: 0.343 loss_val 5.895760054526998 accuracy_validation: 0.339
# epochs:  8 loss_train:  5.484173018721858 accuracy_train: 0.363 loss_val 5.57325611440853 accuracy_validation: 0.361
# epochs:  9 loss_train:  5.148707357577907 accuracy_train: 0.392 loss_val 5.183263011905358 accuracy_validation: 0.379
# epochs:  10 loss_train:  4.712276577883487 accuracy_train: 0.422 loss_val 4.744623348670621 accuracy_validation: 0.427
# epochs:  11 loss_train:  4.461023267179267 accuracy_train: 0.429 loss_val 4.499544742891232 accuracy_validation: 0.45
# epochs:  12 loss_train:  4.191366645161836 accuracy_train: 0.448 loss_val 4.221314477412059 accuracy_validation: 0.472
# epochs:  13 loss_train:  3.9981786410317772 accuracy_train: 0.462 loss_val 4.0439526379124935 accuracy_validation: 0.483
# epochs:  14 loss_train:  3.884340196051891 accuracy_train: 0.476 loss_val 3.937382952387292 accuracy_validation: 0.488
# epochs:  15 loss_train:  3.70043336046087 accuracy_train: 0.486 loss_val 3.7938967088546534 accuracy_validation: 0.501
# epochs:  16 loss_train:  3.563052800125516 accuracy_train: 0.495 loss_val 3.6850875329634607 accuracy_validation: 0.512
# epochs:  17 loss_train:  3.470622631818928 accuracy_train: 0.504 loss_val 3.600420485035611 accuracy_validation: 0.526
# epochs:  18 loss_train:  3.3408551021076045 accuracy_train: 0.518 loss_val 3.4836160790908552 accuracy_validation: 0.54
# epochs:  19 loss_train:  3.200963397868296 accuracy_train: 0.527 loss_val 3.3686916438488392 accuracy_validation: 0.547
# epochs:  20 loss_train:  3.155080896493674 accuracy_train: 0.532 loss_val 3.3429492054035945 accuracy_validation: 0.548
# epochs:  21 loss_train:  3.055318411961974 accuracy_train: 0.543 loss_val 3.269407107199944 accuracy_validation: 0.554
# epochs:  22 loss_train:  2.970471286823929 accuracy_train: 0.549 loss_val 3.2057557105709584 accuracy_validation: 0.56
# epochs:  23 loss_train:  2.9278108923156085 accuracy_train: 0.553 loss_val 3.197218793152466 accuracy_validation: 0.558
# epochs:  24 loss_train:  2.839552703809973 accuracy_train: 0.555 loss_val 3.119048280307473 accuracy_validation: 0.554
# epochs:  25 loss_train:  2.7746936170099197 accuracy_train: 0.561 loss_val 3.060856704401763 accuracy_validation: 0.561
# epochs:  26 loss_train:  2.788829466292267 accuracy_train: 0.563 loss_val 3.091395083061796 accuracy_validation: 0.563
# epochs:  27 loss_train:  2.681172640685546 accuracy_train: 0.572 loss_val 2.9934550642480873 accuracy_validation: 0.577
# epochs:  28 loss_train:  2.613926221391651 accuracy_train: 0.576 loss_val 2.9287098171337114 accuracy_validation: 0.58
# epochs:  29 loss_train:  2.649998053350505 accuracy_train: 0.585 loss_val 2.9557887224466213 accuracy_validation: 0.578
# train (2.649998053350505, 0.585)
# val (2.9557887224466213, 0.578)
# test (3.546165774931247, 0.5144)

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 8, l_rate = 0.05, activeFuncion="relu")
pool1 = MaxPoolingLayer(2)
CNN2 = Convolutional(input_shape = (8,13,13), kernel_size = 3,output_depth = 16, l_rate = 0.05, activeFuncion= "relu")
pool2 = MaxPoolingLayer(2)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[576,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.05) # 16*6*6 = 576
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# epochs:  0 loss_train:  10.769055939141719 accuracy_train: 0.207 loss_val 10.726596954461847 accuracy_validation: 0.203
# epochs:  1 loss_train:  9.194058195571124 accuracy_train: 0.308 loss_val 9.45393762424271 accuracy_validation: 0.291
# epochs:  2 loss_train:  9.30857058751041 accuracy_train: 0.291 loss_val 9.70566191016177 accuracy_validation: 0.26
# epochs:  3 loss_train:  8.686755520519078 accuracy_train: 0.336 loss_val 8.83173756612974 accuracy_validation: 0.314
# epochs:  4 loss_train:  7.864740248946505 accuracy_train: 0.397 loss_val 7.836679354134245 accuracy_validation: 0.39
# epochs:  5 loss_train:  7.790507682442838 accuracy_train: 0.397 loss_val 7.677240059522976 accuracy_validation: 0.396
# epochs:  6 loss_train:  7.243737020772746 accuracy_train: 0.432 loss_val 7.374868719235586 accuracy_validation: 0.426
# epochs:  7 loss_train:  6.7844992979670256 accuracy_train: 0.456 loss_val 6.807760568583029 accuracy_validation: 0.448
# epochs:  8 loss_train:  6.753213444422474 accuracy_train: 0.473 loss_val 6.625981683459506 accuracy_validation: 0.486
# epochs:  9 loss_train:  6.098763565877546 accuracy_train: 0.513 loss_val 6.302590180314395 accuracy_validation: 0.506
# epochs:  10 loss_train:  6.372980498070984 accuracy_train: 0.501 loss_val 6.53315100729245 accuracy_validation: 0.497
# epochs:  11 loss_train:  5.350432696288531 accuracy_train: 0.566 loss_val 5.83354752343665 accuracy_validation: 0.546
# epochs:  12 loss_train:  5.711607262850772 accuracy_train: 0.556 loss_val 6.166906111227943 accuracy_validation: 0.517
# epochs:  13 loss_train:  6.44006036775846 accuracy_train: 0.486 loss_val 6.527668848669444 accuracy_validation: 0.491
# epochs:  14 loss_train:  5.444628721091102 accuracy_train: 0.568 loss_val 5.584599170601201 accuracy_validation: 0.571
# epochs:  15 loss_train:  7.330467257347155 accuracy_train: 0.451 loss_val 7.222832659720565 accuracy_validation: 0.454
# epochs:  16 loss_train:  8.774770091450693 accuracy_train: 0.352 loss_val 8.253980589902746 accuracy_validation: 0.389
# epochs:  17 loss_train:  7.2437996940138945 accuracy_train: 0.462 loss_val 6.809659268078672 accuracy_validation: 0.49
# epochs:  18 loss_train:  7.620365869834037 accuracy_train: 0.434 loss_val 7.039800181735465 accuracy_validation: 0.481
# epochs:  19 loss_train:  6.733652766284171 accuracy_train: 0.504 loss_val 6.331344099376199 accuracy_validation: 0.534
# epochs:  20 loss_train:  7.41553916884452 accuracy_train: 0.452 loss_val 6.8526392458854755 accuracy_validation: 0.497
# epochs:  21 loss_train:  5.759725055135907 accuracy_train: 0.574 loss_val 5.222026456280324 accuracy_validation: 0.607
# epochs:  22 loss_train:  7.470145570885126 accuracy_train: 0.453 loss_val 7.517873798126369 accuracy_validation: 0.451
# epochs:  23 loss_train:  6.124613641348196 accuracy_train: 0.549 loss_val 5.874595290532091 accuracy_validation: 0.568
# epochs:  24 loss_train:  7.433495031895758 accuracy_train: 0.457 loss_val 7.60212509961227 accuracy_validation: 0.445
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       6 nn = NeuralNetwork(layers_size=[576,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.05) # 16*6*6 = 576
#       7 model = Model([CNN1,pool1,CNN2,pool2],nn)
# ----> 8 model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 30)
#      10 print("train", model.test(x_train, y_train))
#      12 print("val", model.test(x_validation, y_validation))
#
# File c:\Users\dotie\Máy tính\Multi-layer-Perceptron\CNN.py:199, in Model.train(self, x_train, y_train, x_val, y_val, batch_size, epochs)
#     197     back_prop.append(gradY[j])
#     198     for layer in reversed(self.CNN_layers):
# --> 199       back_prop.append(layer.backpropagation(back_prop[-1]))
#     200 (loss_train, acuracy_train) = self.test(x_train, y_train)
#     201 (loss_val,accuracy_val) = self.test(x_val,y_val)
#
# File c:\Users\dotie\Máy tính\Multi-layer-Perceptron\CNN.py:107, in Convolutional.backpropagation(self, gradY)
#     105     root_kernel[i][j] = np.rot90(self.kernel[i][j], 2)
#     106     grad_input[j] += self.conv(gradY[i], root_kernel[i][j], padding = root_kernel[i][j].shape[0] - 1)
# --> 107     grad_kernel[i][j] = self.conv(self.input[j], gradY[i], padding = 0)
#     108 self.kernel -= self.l_rate*grad_kernel
#     109 self.bias -= self.l_rate*gradY
#
# File c:\Users\dotie\Máy tính\Multi-layer-Perceptron\CNN.py:52, in Convolutional.conv(self, image, kernel, padding)
#      50 for i in range (out_put_height):
#      51   for j in range (out_put_width):
# ---> 52     output[i][j] = np.sum(padded_image[i:i+kernel_shape[0],j:j + kernel_shape[1]]*kernel)
#      53 return output
#
# File c:\Users\dotie\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\fromnumeric.py:2172, in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2102     """
#    2103     Clip (limit) the values in an array.
#    2104
#    (...)
#    2167
#    2168     """
#    2169     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
# -> 2172 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2173                     initial=None, where=None):
#    2174     return (a, out)
#    2177 @array_function_dispatch(_sum_dispatcher)
#    2178 def sum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2179         initial=np._NoValue, where=np._NoValue):
#
# KeyboardInterrupt:

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 8, l_rate = 0.01, activeFuncion="relu")
pool1 = MaxPoolingLayer(2)
CNN2 = Convolutional(input_shape = (8,13,13), kernel_size = 3,output_depth = 16, l_rate = 0.01, activeFuncion= "relu")
pool2 = MaxPoolingLayer(2)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[576,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.01) # 16*6*6 = 576
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# epochs:  0 loss_train:  12.06053245574655 accuracy_train: 0.106 loss_val 11.804827460009966 accuracy_validation: 0.123
# epochs:  1 loss_train:  11.962502112489194 accuracy_train: 0.113 loss_val 11.502790294920812 accuracy_validation: 0.141
# epochs:  2 loss_train:  11.705782059159777 accuracy_train: 0.127 loss_val 11.337273146339903 accuracy_validation: 0.149
# epochs:  3 loss_train:  11.57894775302913 accuracy_train: 0.141 loss_val 10.989486552996082 accuracy_validation: 0.177
# epochs:  4 loss_train:  11.217065369798972 accuracy_train: 0.159 loss_val 10.679290469100826 accuracy_validation: 0.194
# epochs:  5 loss_train:  11.050487667416906 accuracy_train: 0.166 loss_val 10.553360201714732 accuracy_validation: 0.211
# epochs:  6 loss_train:  10.78414380880088 accuracy_train: 0.19 loss_val 10.231007448309622 accuracy_validation: 0.223
# epochs:  7 loss_train:  10.469269645559997 accuracy_train: 0.211 loss_val 10.02190381710512 accuracy_validation: 0.24
# epochs:  8 loss_train:  10.22830616025096 accuracy_train: 0.217 loss_val 9.739531185119002 accuracy_validation: 0.257
# epochs:  9 loss_train:  10.029606095511292 accuracy_train: 0.242 loss_val 9.43578082178699 accuracy_validation: 0.272
# epochs:  10 loss_train:  9.880044266015908 accuracy_train: 0.25 loss_val 9.224290894112247 accuracy_validation: 0.292
# epochs:  11 loss_train:  9.710992623914716 accuracy_train: 0.27 loss_val 8.996762500469792 accuracy_validation: 0.315
# epochs:  12 loss_train:  9.479710198720198 accuracy_train: 0.278 loss_val 8.804151539061468 accuracy_validation: 0.324
# epochs:  13 loss_train:  9.277637890788425 accuracy_train: 0.297 loss_val 8.606970376786668 accuracy_validation: 0.333
# epochs:  14 loss_train:  9.213953502267673 accuracy_train: 0.299 loss_val 8.433118754510417 accuracy_validation: 0.358
# epochs:  15 loss_train:  8.926408660443908 accuracy_train: 0.315 loss_val 8.14761469460238 accuracy_validation: 0.372
# epochs:  16 loss_train:  8.607303661859298 accuracy_train: 0.336 loss_val 7.932534498658414 accuracy_validation: 0.393
# epochs:  17 loss_train:  8.442222434943695 accuracy_train: 0.356 loss_val 7.792672489251529 accuracy_validation: 0.403
# epochs:  18 loss_train:  8.237602885963238 accuracy_train: 0.361 loss_val 7.615465541115867 accuracy_validation: 0.419
# epochs:  19 loss_train:  8.074284970677846 accuracy_train: 0.373 loss_val 7.422078529798694 accuracy_validation: 0.424
# epochs:  20 loss_train:  7.8724896199437815 accuracy_train: 0.383 loss_val 7.231971255551161 accuracy_validation: 0.432
# epochs:  21 loss_train:  7.643397275270021 accuracy_train: 0.401 loss_val 6.985919750994363 accuracy_validation: 0.449
# epochs:  22 loss_train:  7.5332671972337755 accuracy_train: 0.408 loss_val 6.839964544163658 accuracy_validation: 0.465
# epochs:  23 loss_train:  7.442572203110706 accuracy_train: 0.421 loss_val 6.668009073798696 accuracy_validation: 0.477
# epochs:  24 loss_train:  7.1940586064431535 accuracy_train: 0.432 loss_val 6.562730100564635 accuracy_validation: 0.493
# epochs:  25 loss_train:  6.960341688512333 accuracy_train: 0.445 loss_val 6.330535397753196 accuracy_validation: 0.505
# epochs:  26 loss_train:  6.827911136476911 accuracy_train: 0.448 loss_val 6.20422981948583 accuracy_validation: 0.51
# epochs:  27 loss_train:  6.682290091073026 accuracy_train: 0.469 loss_val 6.088738098523205 accuracy_validation: 0.518
# epochs:  28 loss_train:  6.536121132381897 accuracy_train: 0.478 loss_val 5.906424705268932 accuracy_validation: 0.532
# epochs:  29 loss_train:  6.431324551571522 accuracy_train: 0.49 loss_val 5.681563750747289 accuracy_validation: 0.55
# train (6.431324551571522, 0.49)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 12
#       8 model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 30)
#      10 print("train", model.test(x_train, y_train))
# ---> 12 print("val", model.test(x_validation, y_validation))
#      14 print("test", model.test(x_test,y_test))
#
# File c:\Users\dotie\Máy tính\Multi-layer-Perceptron\CNN.py:211, in Model.test(self, x_test, y_test)
#     209   output[j] = np.expand_dims(x_test[j], axis=0)
#     210   for layer in self.CNN_layers:
# --> 211     output[j] = layer.forward(output[j])
#     212 output_array = self.flatten.forward(output)
#     213 Y_hat = self.nn_layer.forward(output_array)
#
# File c:\Users\dotie\Máy tính\Multi-layer-Perceptron\CNN.py:79, in Convolutional.forward(self, input)
#      77 def forward(self, input):
#      78   self.input = np.array(input)
# ---> 79   self.output = np.zeros(self.output_shape)
#      80   for j in range (self.output_shape[0]):
#      81     for i in range (self.input_shape[0]):
#
# KeyboardInterrupt:

# %%
model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 20)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# epochs:  0 loss_train:  6.291607578297376 accuracy_train: 0.5 loss_val 5.606187546127635 accuracy_validation: 0.553
# epochs:  1 loss_train:  6.158263137472244 accuracy_train: 0.503 loss_val 5.497402908876786 accuracy_validation: 0.567
# epochs:  2 loss_train:  6.014320957112522 accuracy_train: 0.522 loss_val 5.448683805822802 accuracy_validation: 0.56
# epochs:  3 loss_train:  5.902169296331691 accuracy_train: 0.529 loss_val 5.406893669651097 accuracy_validation: 0.577
# epochs:  4 loss_train:  5.80571652987772 accuracy_train: 0.534 loss_val 5.233642135661507 accuracy_validation: 0.585
# epochs:  5 loss_train:  5.862213432128262 accuracy_train: 0.525 loss_val 5.3525030936244855 accuracy_validation: 0.577
# epochs:  6 loss_train:  5.711221006758983 accuracy_train: 0.54 loss_val 5.262584571040868 accuracy_validation: 0.593
# epochs:  7 loss_train:  5.667370474439983 accuracy_train: 0.545 loss_val 5.229546907399805 accuracy_validation: 0.593
# epochs:  8 loss_train:  5.681044365546476 accuracy_train: 0.546 loss_val 5.320829495905905 accuracy_validation: 0.579
# epochs:  9 loss_train:  5.694089704539255 accuracy_train: 0.543 loss_val 5.3201628870568465 accuracy_validation: 0.587
# epochs:  10 loss_train:  5.677607975502001 accuracy_train: 0.545 loss_val 5.345598543348192 accuracy_validation: 0.588
# epochs:  11 loss_train:  5.785365425913836 accuracy_train: 0.538 loss_val 5.4229697033500495 accuracy_validation: 0.586
# epochs:  12 loss_train:  5.409217709602038 accuracy_train: 0.568 loss_val 5.310087581987189 accuracy_validation: 0.577
# epochs:  13 loss_train:  5.5018098553418815 accuracy_train: 0.557 loss_val 5.379924650293555 accuracy_validation: 0.584
# epochs:  14 loss_train:  5.661903382023951 accuracy_train: 0.549 loss_val 5.443495082117827 accuracy_validation: 0.579
# epochs:  15 loss_train:  5.537757272386414 accuracy_train: 0.56 loss_val 5.4346282041850005 accuracy_validation: 0.581
# epochs:  16 loss_train:  5.630900188240684 accuracy_train: 0.55 loss_val 5.5169682708686345 accuracy_validation: 0.574
# epochs:  17 loss_train:  5.64886347526701 accuracy_train: 0.553 loss_val 5.543339664940417 accuracy_validation: 0.571
# epochs:  18 loss_train:  5.680206178521145 accuracy_train: 0.551 loss_val 5.548761009755711 accuracy_validation: 0.574
# epochs:  19 loss_train:  5.95459528717982 accuracy_train: 0.531 loss_val 5.578466117016873 accuracy_validation: 0.568
# train (5.95459528717982, 0.531)
# val (5.578466117016873, 0.568)
# test (6.5928878160638344, 0.4934)

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 4, l_rate = 0.05, activeFuncion="relu")
pool1 = MaxPoolingLayer(2)
CNN2 = Convolutional(input_shape = (4,13,13), kernel_size = 3,output_depth = 8, l_rate = 0.05, activeFuncion= "relu")
pool2 = MaxPoolingLayer(2)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[288,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.05) # 8*6*6 = 576
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# loss_train:  11.403887060903827 accuracy_train: 0.102
# loss_train:  11.653424079516277 accuracy_train: 0.075
# loss_train:  11.07395441017594 accuracy_train: 0.108
# loss_train:  10.768064590047661 accuracy_train: 0.124
# loss_train:  10.532763280535395 accuracy_train: 0.132
# loss_train:  10.11885582765671 accuracy_train: 0.148
# loss_train:  9.663535439693021 accuracy_train: 0.182
# loss_train:  9.297923301157375 accuracy_train: 0.198
# loss_train:  8.786695797378798 accuracy_train: 0.223
# loss_train:  8.317582215880188 accuracy_train: 0.241
# loss_train:  7.813881391696304 accuracy_train: 0.295
# loss_train:  8.210746086392074 accuracy_train: 0.287
# loss_train:  7.255597129525247 accuracy_train: 0.334
# loss_train:  7.594200243329287 accuracy_train: 0.339
# loss_train:  8.279994543599265 accuracy_train: 0.301
# loss_train:  9.2587187247879 accuracy_train: 0.263
# loss_train:  9.70143591904502 accuracy_train: 0.248
# loss_train:  9.642387774367878 accuracy_train: 0.263
# loss_train:  8.878165388214065 accuracy_train: 0.32
# loss_train:  8.119130618453147 accuracy_train: 0.371
# loss_train:  7.445155404506428 accuracy_train: 0.419
# loss_train:  6.888718741122012 accuracy_train: 0.461
# loss_train:  6.235880547684081 accuracy_train: 0.502
# loss_train:  5.941936232005308 accuracy_train: 0.528
# loss_train:  5.326969389428616 accuracy_train: 0.579
# loss_train:  4.955658944955081 accuracy_train: 0.59
# loss_train:  4.467133919087184 accuracy_train: 0.634
# loss_train:  4.15349264127067 accuracy_train: 0.653
# loss_train:  4.1267358201854245 accuracy_train: 0.655
# loss_train:  4.096925788499888 accuracy_train: 0.658
# train (4.096925788499888, 0.658)
# val (4.144042455658763, 0.65)
# test (4.909233271536168, 0.5973)

# %%
model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# loss_train:  4.131057032569783 accuracy_train: 0.653
# loss_train:  4.010104128725112 accuracy_train: 0.656
# loss_train:  3.7442298045389943 accuracy_train: 0.684
# loss_train:  3.634656729775038 accuracy_train: 0.698
# loss_train:  3.5450528592090547 accuracy_train: 0.705
# loss_train:  3.39050753187597 accuracy_train: 0.712
# loss_train:  3.3449437425527795 accuracy_train: 0.712
# loss_train:  3.314945454113521 accuracy_train: 0.709
# loss_train:  3.309328513291367 accuracy_train: 0.712
# loss_train:  3.0076731924008837 accuracy_train: 0.744
# loss_train:  3.1529005149143945 accuracy_train: 0.73
# loss_train:  3.0820915664122497 accuracy_train: 0.728
# loss_train:  3.171806167082233 accuracy_train: 0.727
# loss_train:  3.3413173432313727 accuracy_train: 0.719
# loss_train:  3.3398502271201562 accuracy_train: 0.717
# loss_train:  3.277579098328268 accuracy_train: 0.727
# loss_train:  3.0266176781794667 accuracy_train: 0.736
# loss_train:  2.818296406995593 accuracy_train: 0.761
# loss_train:  2.819786042497986 accuracy_train: 0.755
# loss_train:  2.6308789861742072 accuracy_train: 0.772
# loss_train:  2.5152333325378726 accuracy_train: 0.785
# loss_train:  2.4668501194302705 accuracy_train: 0.787
# loss_train:  2.5921841805537618 accuracy_train: 0.782
# loss_train:  2.43352844837116 accuracy_train: 0.788
# loss_train:  2.4211362406804664 accuracy_train: 0.794
# loss_train:  2.730197847487133 accuracy_train: 0.771
# loss_train:  3.2088268055236076 accuracy_train: 0.741
# loss_train:  3.5643960928932645 accuracy_train: 0.727
# loss_train:  3.6789703695673897 accuracy_train: 0.716
# loss_train:  4.186391479790599 accuracy_train: 0.683
# train (4.186391479790599, 0.683)
# val (4.02394509916439, 0.7)
# test (4.899143054315169, 0.6331)

# %%
model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# loss_train:  5.336782218638974 accuracy_train: 0.6
# loss_train:  3.952106190977986 accuracy_train: 0.699
# loss_train:  2.859889290820217 accuracy_train: 0.783
# loss_train:  3.636855562798164 accuracy_train: 0.723
# loss_train:  3.2883068426237347 accuracy_train: 0.745
# loss_train:  2.4126800227172507 accuracy_train: 0.814
# loss_train:  2.3197726292044405 accuracy_train: 0.82
# loss_train:  2.653681868451917 accuracy_train: 0.787
# loss_train:  2.38880885878723 accuracy_train: 0.811
# loss_train:  2.6838225967341285 accuracy_train: 0.797
# loss_train:  2.99165963395986 accuracy_train: 0.769
# loss_train:  2.259636532688944 accuracy_train: 0.821
# loss_train:  2.160865154389133 accuracy_train: 0.833
# loss_train:  1.7351540680490805 accuracy_train: 0.86
# loss_train:  2.2634313171032727 accuracy_train: 0.826
# loss_train:  2.3386336945662087 accuracy_train: 0.823
# loss_train:  1.8885999486304852 accuracy_train: 0.851
# loss_train:  2.4108511063141465 accuracy_train: 0.814
# loss_train:  3.3665817729856777 accuracy_train: 0.75
# loss_train:  2.0952587944911976 accuracy_train: 0.837
# loss_train:  3.730099826256974 accuracy_train: 0.719
# loss_train:  3.718637319926932 accuracy_train: 0.725
# loss_train:  3.996394765574684 accuracy_train: 0.704
# loss_train:  4.480091798355528 accuracy_train: 0.668
# loss_train:  5.819501579077986 accuracy_train: 0.574
# loss_train:  4.0148513514416 accuracy_train: 0.7
# loss_train:  3.4375290173954722 accuracy_train: 0.744
# loss_train:  3.163535891362292 accuracy_train: 0.764
# loss_train:  2.1564520047251667 accuracy_train: 0.839
# loss_train:  3.7752102042858597 accuracy_train: 0.72
# train (3.7752102042858597, 0.72)
# val (4.407279211265126, 0.674)
# test (4.5357407794460505, 0.6666)

# %%
CNN1 = Convolutional(input_shape = (1,28,28), kernel_size = 3, output_depth = 4, l_rate = 0.03, activeFuncion="relu")
pool1 = MaxPoolingLayer(2)
CNN2 = Convolutional(input_shape = (4,13,13), kernel_size = 3,output_depth = 8, l_rate = 0.03, activeFuncion= "relu")
pool2 = MaxPoolingLayer(2)
flatten = Flattening()
nn = NeuralNetwork(layers_size=[288,10],activations = ["", "softmax"], loss = "crossEntropy", l_rate = 0.03) # 8*6*6 = 576
model = Model([CNN1,pool1,CNN2,pool2],nn)
model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 50)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# loss_train:  11.000567475459883 accuracy_train: 0.126
# loss_train:  10.657850588587465 accuracy_train: 0.154
# loss_train:  10.075070786768261 accuracy_train: 0.186
# loss_train:  9.686395219375514 accuracy_train: 0.21
# loss_train:  9.805708002511512 accuracy_train: 0.198
# loss_train:  9.372138797908082 accuracy_train: 0.219
# loss_train:  9.051481545054992 accuracy_train: 0.239
# loss_train:  8.652505865265265 accuracy_train: 0.266
# loss_train:  8.167823916859367 accuracy_train: 0.296
# loss_train:  7.7880800864553725 accuracy_train: 0.323
# loss_train:  7.467298253617335 accuracy_train: 0.349
# loss_train:  7.159903332629398 accuracy_train: 0.375
# loss_train:  6.969376765192706 accuracy_train: 0.393
# loss_train:  6.772614897582535 accuracy_train: 0.404
# loss_train:  6.5775263348948885 accuracy_train: 0.416
# loss_train:  6.368853408126899 accuracy_train: 0.433
# loss_train:  6.235565704261444 accuracy_train: 0.441
# loss_train:  6.085175839761384 accuracy_train: 0.455
# loss_train:  5.923646251995426 accuracy_train: 0.459
# loss_train:  5.8135696077563335 accuracy_train: 0.468
# loss_train:  5.731410542273794 accuracy_train: 0.481
# loss_train:  5.622959917066462 accuracy_train: 0.494
# loss_train:  5.485321046307853 accuracy_train: 0.503
# loss_train:  5.366104197819539 accuracy_train: 0.521
# loss_train:  5.260627785499209 accuracy_train: 0.53
# loss_train:  5.144642131696052 accuracy_train: 0.538
# loss_train:  5.042041864363833 accuracy_train: 0.541
# loss_train:  4.960379947127529 accuracy_train: 0.551
# loss_train:  4.8444689655246425 accuracy_train: 0.551
# loss_train:  4.817347233146482 accuracy_train: 0.561
# loss_train:  4.71898002295475 accuracy_train: 0.568
# loss_train:  4.667488833495177 accuracy_train: 0.572
# loss_train:  4.579547323518557 accuracy_train: 0.578
# loss_train:  4.6577323928501 accuracy_train: 0.572
# loss_train:  4.6375779205392496 accuracy_train: 0.573
# loss_train:  4.550944998466697 accuracy_train: 0.582
# loss_train:  4.488881531906017 accuracy_train: 0.588
# loss_train:  4.3764950957934206 accuracy_train: 0.591
# loss_train:  4.342903288522283 accuracy_train: 0.598
# loss_train:  4.268647143751976 accuracy_train: 0.604
# loss_train:  4.212490536555741 accuracy_train: 0.611
# loss_train:  4.123445270824839 accuracy_train: 0.619
# loss_train:  4.055295164567007 accuracy_train: 0.625
# loss_train:  4.013767297473152 accuracy_train: 0.626
# loss_train:  4.0164993252549674 accuracy_train: 0.624
# loss_train:  3.9755061740012887 accuracy_train: 0.627
# loss_train:  3.9917406252637133 accuracy_train: 0.628
# loss_train:  3.9773416646507065 accuracy_train: 0.627
# loss_train:  3.9807973116561386 accuracy_train: 0.635
# loss_train:  3.923661254440055 accuracy_train: 0.638
# train (3.923661254440055, 0.638)
# val (3.9370170818391634, 0.652)
# test (4.602759576930337, 0.5896)

# %%
model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 50)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# loss_train:  3.8871264398126977 accuracy_train: 0.642
# loss_train:  3.791920419018384 accuracy_train: 0.646
# loss_train:  3.773594157258592 accuracy_train: 0.65
# loss_train:  3.7217579690122444 accuracy_train: 0.662
# loss_train:  3.6509220861556546 accuracy_train: 0.668
# loss_train:  3.6179514214837547 accuracy_train: 0.67
# loss_train:  3.580953973116393 accuracy_train: 0.67
# loss_train:  3.528260708778985 accuracy_train: 0.679
# loss_train:  3.495789604115491 accuracy_train: 0.681
# loss_train:  3.466598888150608 accuracy_train: 0.683
# loss_train:  3.466230620335773 accuracy_train: 0.684
# loss_train:  3.446414008984346 accuracy_train: 0.683
# loss_train:  3.408392499248145 accuracy_train: 0.691
# loss_train:  3.3810630790594187 accuracy_train: 0.691
# loss_train:  3.35341601086802 accuracy_train: 0.693
# loss_train:  3.3140028301881816 accuracy_train: 0.689
# loss_train:  3.2615090296746128 accuracy_train: 0.697
# loss_train:  3.2178678615067464 accuracy_train: 0.704
# loss_train:  3.1560377278258662 accuracy_train: 0.708
# loss_train:  3.133620725405634 accuracy_train: 0.71
# loss_train:  3.1136789940117673 accuracy_train: 0.711
# loss_train:  3.0780199716924717 accuracy_train: 0.713
# loss_train:  3.0539692803294916 accuracy_train: 0.712
# loss_train:  3.001358381330484 accuracy_train: 0.718
# loss_train:  2.97563714596329 accuracy_train: 0.72
# loss_train:  2.9252510671845404 accuracy_train: 0.721
# loss_train:  2.87990459153795 accuracy_train: 0.725
# loss_train:  2.857320548715688 accuracy_train: 0.725
# loss_train:  2.840705443357501 accuracy_train: 0.727
# loss_train:  2.828719833557335 accuracy_train: 0.728
# loss_train:  2.8096553278245295 accuracy_train: 0.727
# loss_train:  2.7835559209500835 accuracy_train: 0.732
# loss_train:  2.7629671078694042 accuracy_train: 0.734
# loss_train:  2.745040992252252 accuracy_train: 0.74
# loss_train:  2.7021291145440283 accuracy_train: 0.741
# loss_train:  2.666372734885461 accuracy_train: 0.744
# loss_train:  2.6556319978043295 accuracy_train: 0.743
# loss_train:  2.646198899148975 accuracy_train: 0.745
# loss_train:  2.652193288003056 accuracy_train: 0.743
# loss_train:  2.6482703319176264 accuracy_train: 0.744
# loss_train:  2.6194428729415984 accuracy_train: 0.747
# loss_train:  2.5658493937170324 accuracy_train: 0.754
# loss_train:  2.5523404309870186 accuracy_train: 0.754
# loss_train:  2.5020026459825506 accuracy_train: 0.756
# loss_train:  2.5220692999150978 accuracy_train: 0.757
# loss_train:  2.504062389835659 accuracy_train: 0.761
# loss_train:  2.5057331595355317 accuracy_train: 0.762
# loss_train:  2.487720297079966 accuracy_train: 0.76
# loss_train:  2.457033532761016 accuracy_train: 0.762
# loss_train:  2.440271257564491 accuracy_train: 0.762
# train (2.440271257564491, 0.762)
# val (3.250817797609746, 0.716)
# test (3.6691988528938, 0.6771)

# %%
model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# loss_train:  2.4155367096443676 accuracy_train: 0.759
# loss_train:  2.5002892634304374 accuracy_train: 0.755
# loss_train:  2.4798289455329328 accuracy_train: 0.755
# loss_train:  2.340605708124147 accuracy_train: 0.767
# loss_train:  2.3719548154717067 accuracy_train: 0.767
# loss_train:  2.3116524520672628 accuracy_train: 0.769
# loss_train:  2.3656195868070946 accuracy_train: 0.761
# loss_train:  2.3851619116237472 accuracy_train: 0.758
# loss_train:  2.3831880733070885 accuracy_train: 0.759
# loss_train:  2.3287382972153092 accuracy_train: 0.765
# loss_train:  2.3467579803288396 accuracy_train: 0.762
# loss_train:  2.297809056227873 accuracy_train: 0.767
# loss_train:  2.30245236822767 accuracy_train: 0.772
# loss_train:  2.2893655546134495 accuracy_train: 0.772
# loss_train:  2.339934136075296 accuracy_train: 0.781
# loss_train:  2.408183943028088 accuracy_train: 0.773
# loss_train:  2.409672242233238 accuracy_train: 0.776
# loss_train:  2.3905495495695086 accuracy_train: 0.775
# loss_train:  2.343518238557881 accuracy_train: 0.771
# loss_train:  2.283689292955829 accuracy_train: 0.779
# loss_train:  2.2812740700428296 accuracy_train: 0.786
# loss_train:  2.257133731429549 accuracy_train: 0.786
# loss_train:  2.278150419037946 accuracy_train: 0.782
# loss_train:  2.2171821954740656 accuracy_train: 0.793
# loss_train:  2.22089241249696 accuracy_train: 0.796
# loss_train:  2.1706153021213543 accuracy_train: 0.794
# loss_train:  2.1583752672172594 accuracy_train: 0.794
# loss_train:  2.1367847489407805 accuracy_train: 0.795
# loss_train:  2.164713351054238 accuracy_train: 0.799
# loss_train:  2.190188031329554 accuracy_train: 0.794
# train (2.190188031329554, 0.794)
# val (3.150345153765209, 0.73)
# test (3.453966490251484, 0.7006)

# %%
model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 30)

print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# x_train:  (1000, 28, 28)
# y_train:  (10, 1000)
# x_val:  (1000, 28, 28)
# y_val:  (10, 1000)
# loss_train:  2.2262929316790427 accuracy_train: 0.796
# loss_train:  2.212820962965619 accuracy_train: 0.796
# loss_train:  2.228612638659382 accuracy_train: 0.796
# loss_train:  2.2022670492585195 accuracy_train: 0.796
# loss_train:  2.149725545275987 accuracy_train: 0.801
# loss_train:  2.147522144929932 accuracy_train: 0.802
# loss_train:  2.1037698783455903 accuracy_train: 0.804
# loss_train:  2.021356846336762 accuracy_train: 0.811
# loss_train:  2.048715115144934 accuracy_train: 0.812
# loss_train:  2.0454725119657033 accuracy_train: 0.811
# loss_train:  2.0167739597713266 accuracy_train: 0.813
# loss_train:  2.0609966504510497 accuracy_train: 0.805
# loss_train:  2.1000708771572207 accuracy_train: 0.803
# loss_train:  2.1577906741003114 accuracy_train: 0.798
# loss_train:  2.114564801300478 accuracy_train: 0.798
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model.train(x_train,y_train,x_validation,y_validation, batch_size = 32, epochs = 30)
#       3 print("train", model.test(x_train, y_train))
#       5 print("val", model.test(x_validation, y_validation))
#
# File c:\Users\dotie\Máy tính\Multi-layer-Perceptron\CNN.py:200, in Model.train(self, x_train, y_train, x_val, y_val, batch_size, epochs)
#     198     for layer in reversed(self.CNN_layers):
#     199       back_prop.append(layer.backpropagation(back_prop[-1]))
# --> 200 (loss_train, acuracy_train) = self.test(x_train, y_train)
#     201 print("loss_train: ", loss_train, "accuracy_train:", acuracy_train)
#
# File c:\Users\dotie\Máy tính\Multi-layer-Perceptron\CNN.py:213, in Model.test(self, x_test, y_test)
#     211   output[j] = np.expand_dims(x_test[j], axis=0)
#     212   for layer in self.CNN_layers:
# --> 213     output[j] = layer.forward(output[j])
#     214 output_array = self.flatten.forward(output)
#     215 Y_hat = self.nn_layer.forward(output_array)
#
# File c:\Users\dotie\Máy tính\Multi-layer-Perceptron\CNN.py:82, in Convolutional.forward(self, input)
#      80 for j in range (self.output_shape[0]):
#      81   for i in range (self.input_shape[0]):
# ---> 82       self.output[j] += self.conv(self.input[i], self.kernel[j][i], padding = 0)
#      83   self.output[j] += self.bias[j]
#      84 self.output = self.active(self.output)
#
# File c:\Users\dotie\Máy tính\Multi-layer-Perceptron\CNN.py:42, in Convolutional.conv(self, image, kernel, padding)
#      41 def conv(self, image, kernel, padding):
# ---> 42   image = np.array(image)
#      43   kernel = np.array(kernel)
#      44   img_shape = image.shape
#
# KeyboardInterrupt:

# %%
print("train", model.test(x_train, y_train))

print("val", model.test(x_validation, y_validation))

print("test", model.test(x_test,y_test))
# Out:
# train (2.106359949171203, 0.806)
# val (3.0821096413151334, 0.737)
# test (3.4870791603831726, 0.7079)
